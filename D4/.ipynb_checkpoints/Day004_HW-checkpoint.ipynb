# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11019584897","type":"PullRequestEvent","actor":{"id":16758464,"login":"anafilipadealmeida","display_login":"anafilipadealmeida","gravatar_id":"","url":"https://api.github.com/users/anafilipadealmeida","avatar_url":"https://avatars.githubusercontent.com/u/16758464?"},"repo":{"id":76082423,"name":"bufferapp/buffer-publish","url":"https://api.github.com/repos/bufferapp/buffer-publish"},"payload":{"action":"closed","number":1121,"pull_request":{"url":"https://api.github.com/repos/bufferapp/buffer-publish/pulls/1121","id":349067691,"node_id":"MDExOlB1bGxSZXF1ZXN0MzQ5MDY3Njkx","html_url":"https://github.com/bufferapp/buffer-publish/pull/1121","diff_url":"https://github.com/bufferapp/buffer-publish/pull/1121.diff","patch_url":"https://github.com/bufferapp/buffer-publish/pull/1121.patch","issue_url":"https://api.github.com/repos/bufferapp/buffer-publish/issues/1121","number":1121,"state":"closed","locked":false,"title":"[PUB-2261] Change composer IG warnings style to match BDS","user":{"login":"anafilipadealmeida","id":16758464,"node_id":"MDQ6VXNlcjE2NzU4NDY0","avatar_url":"https://avatars1.githubusercontent.com/u/16758464?v=4","gravatar_id":"","url":"https://api.github.com/users/anafilipadealmeida","html_url":"https://github.com/anafilipadealmeida","followers_url":"https://api.github.com/users/anafilipadealmeida/followers","following_url":"https://api.github.com/users/anafilipadealmeida/following{/other_user}","gists_url":"https://api.github.com/users/anafilipadealmeida/gists{/gist_id}","starred_url":"https://api.github.com/users/anafilipadealmeida/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/anafilipadealmeida/subscriptions","organizations_url":"https://api.github.com/users/anafilipadealmeida/orgs","repos_url":"https://api.github.com/users/anafilipadealmeida/repos","events_url":"https://api.github.com/users/anafilipadealmeida/events{/privacy}","received_events_url":"https://api.github.com/users/anafilipadealmeida/received_events","type":"User","site_admin":false},"body":"<!--- Provide a general summary of your changes in the Title above. -->\\r\\n\\r\\n## Description\\r\\nChange Instagram warning styles in the composer.\\r\\n<!--- Describe your changes in detail. -->\\r\\n\\r\\n## Context & Notes\\r\\n[PUB-2261](https://buffer.atlassian.net/browse/PUB-2261)\\r\\n<!--- Why is this change required? What problem does it solve? -->\\r\\n<!--- Is there a related JIRA card? Please link to it here. -->\\r\\n\\r\\n## Screenshots (if appropriate)\\r\\n![Captura de ecrã 2019-12-04, às 19 48 38](https://user-images.githubusercontent.com/16758464/70176689-ce65ad00-16d0-11ea-8b8e-43b291911002.png)\\r\\n\\r\\n## Checklist\\r\\n\\r\\n<!--- Go over all the following points, and put an `x` in all the boxes that apply. -->\\r\\n\\r\\n-   [x] My code follows the code style and guidelines of this project. <!--- eslint -->\\r\\n-   [ ] I have added tests to cover my changes.\\r\\n-   [x] All new and existing tests passed.\\r\\n-   [x] I have tested different user stories. <!--- e.g. team members, different plans -->\\r\\n-   [x] I have identified similar or related features and tested they are still working.\\r\\n-   [x] I have performed a self-review of my own code.\\r\\n-   [ ] I have tested my changes/additions in the latest Chrome, Firefox, and Safari.\\r\\n-   [ ] I have commented my code, particularly in hard-to-understand areas.\\r\\n\\r\\n#### Staging Deployment\\r\\n\\r\\nTo visit the URL of the staging deployment, please click \\"Show all checks\\" at the bottom of this PR and click \\"details\\" next to `bufferbotbrains/cicd-buffer-publish-legacy`\\r\\n","created_at":"2019-12-04T20:01:33Z","updated_at":"2019-12-05T13:00:41Z","closed_at":"2019-12-05T13:00:41Z","merged_at":"2019-12-05T13:00:40Z","merge_commit_sha":"6a3c8a736cf456df37b5c59189f77c961ac59266","assignee":null,"assignees":[],"requested_reviewers":[{"login":"MayaUribe","id":988972,"node_id":"MDQ6VXNlcjk4ODk3Mg==","avatar_url":"https://avatars3. ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11019584897',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 16758464,
#    'login': 'anafilipadealmeida',
#    'display_login': 'anafilipadealmeida',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/anafilipadealmeida',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16758464?'},
#   'repo': {'id': 76082423,
#    'name': 'bufferapp/buffer-publish',
#    'url': 'https://api.github.com/repos/bufferapp/buffer-publish'},
#   'payload': {'action': 'closed',
#    'number': 1121,
#    'pull_request': {'url': 'https://api.github.com/repos/bufferapp/buffer-publish/pulls/1121',
#     'id': 349067691,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ5MDY3Njkx',
#     'html_url': 'https://github.com/bufferapp/buffer-publish/pull/1121',
#     'diff_url': 'https://github.com/bufferapp/buffer-publish/pull/1121.diff',
#     'patch_url': 'https://github.com/bufferapp/buffer-publish/pull/1121.patch',
#     'issue_url': 'https://api.github.com/repos/bufferapp/buffer-publish/issues/1121',
#     'number': 1121,
#     'state': 'closed',
#     'locked': False,
#     'title': '[PUB-2261] Change composer IG warnings style to match BDS',
#     'user': {'login': 'anafilipadealmeida',
#      'id': 16758464,
#      'node_id': 'MDQ6VXNlcjE2NzU4NDY0',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/16758464?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/anafilipadealmeida',
#      'html_url': 'https://github.com/anafilipadealmeida',
#      'followers_url': 'https://api.github.com/users/anafilipadealmeida/followers',
#      'following_url': 'https://api.github.com/users/anafilipadealmeida/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/anafilipadealmeida/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/anafilipadealmeida/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/anafilipadealmeida/subscriptions',
#      'organizations_url': 'https://api.github.com/users/anafilipadealmeida/orgs',
#      'repos_url': 'https://api.github.com/users/anafilipadealmeida/repos',
#      'events_url': 'https://api.github.com/users/anafilipadealmeida/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/anafilipadealmeida/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '<!--- Provide a general summary of your changes in the Title above. -->\r\n\r\n## Description\r\nChange Instagram warning styles in the composer.\r\n<!--- Describe your changes in detail. -->\r\n\r\n## Context & Notes\r\n[PUB-2261](https://buffer.atlassian.net/browse/PUB-2261)\r\n<!--- Why is this change required? What problem does it solve? -->\r\n<!--- Is there a related JIRA card? Please link to it here. -->\r\n\r\n## Screenshots (if appropriate)\r\n![Captura de ecrã 2019-12-04, às 19 48 38](https://user-images.githubusercontent.com/16758464/70176689-ce65ad00-16d0-11ea-8b8e-43b291911002.png)\r\n\r\n## Checklist\r\n\r\n<!--- Go over all the following points, and put an `x` in all the boxes that apply. -->\r\n\r\n-   [x] My code follows the code style and guidelines of this project. <!--- eslint -->\r\n-   [ ] I have added tests to cover my changes.\r\n-   [x] All new and existing tests passed.\r\n-   [x] I have tested different user stories. <!--- e.g. team members, different plans -->\r\n-   [x] I have identified similar or related features and tested they are still working.\r\n-   [x] I have performed a self-review of my own code.\r\n-   [ ] I have tested my changes/additions in the latest Chrome, Firefox, and Safari.\r\n-   [ ] I have commented my code, particularly in hard-to-understand areas.\r\n\r\n#### Staging Deployment\r\n\r\nTo visit the URL of the staging deployment, please click "Show all checks" at the bottom of this PR and click "details" next to `bufferbotbrains/cicd-buffer-publish-legacy`\r\n',
#     'created_at': '2019-12-04T20:01:33Z',
#     'updated_at': '2019-12-05T13:00:41Z',
#     'closed_at': '2019-12-05T13:00:41Z',
#     'merged_at': '2019-12-05T13:00:40Z',
#     'merge_commit_sha': '6a3c8a736cf456df37b5c59189f77c961ac59266',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [{'login': 'MayaUribe',
#       'id': 988972,
#       'node_id': 'MDQ6VXNlcjk4ODk3Mg==',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/988972?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/MayaUribe',
#       'html_url': 'https://github.com/MayaUribe',
#       'followers_url': 'https://api.github.com/users/MayaUribe/followers',
#       'following_url': 'https://api.github.com/users/MayaUribe/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/MayaUribe/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/MayaUribe/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/MayaUribe/subscriptions',
#       'organizations_url': 'https://api.github.com/users/MayaUribe/orgs',
#       'repos_url': 'https://api.github.com/users/MayaUribe/repos',
#       'events_url': 'https://api.github.com/users/MayaUribe/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/MayaUribe/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/bufferapp/buffer-publish/pulls/1121/commits',
#     'review_comments_url': 'https://api.github.com/repos/bufferapp/buffer-publish/pulls/1121/comments',
#     'review_comment_url': 'https://api.github.com/repos/bufferapp/buffer-publish/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/bufferapp/buffer-publish/issues/1121/comments',
#     'statuses_url': 'https://api.github.com/repos/bufferapp/buffer-publish/statuses/c2c3f7990803d81ec63aa61a476230942e92c839',
#     'head': {'label': 'bufferapp:task/change-composer-ig-warning-styles',
#      'ref': 'task/change-composer-ig-warning-styles',
#      'sha': 'c2c3f7990803d81ec63aa61a476230942e92c839',
#      'user': {'login': 'bufferapp',
#       'id': 798826,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc5ODgyNg==',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/798826?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/bufferapp',
#       'html_url': 'https://github.com/bufferapp',
#       'followers_url': 'https://api.github.com/users/bufferapp/followers',
#       'following_url': 'https://api.github.com/users/bufferapp/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/bufferapp/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/bufferapp/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/bufferapp/subscriptions',
#       'organizations_url': 'https://api.github.com/users/bufferapp/orgs',
#       'repos_url': 'https://api.github.com/users/bufferapp/repos',
#       'events_url': 'https://api.github.com/users/bufferapp/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/bufferapp/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 76082423,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk3NjA4MjQyMw==',
#       'name': 'buffer-publish',
#       'full_name': 'bufferapp/buffer-publish',
#       'private': False,
#       'owner': {'login': 'bufferapp',
#        'id': 798826,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc5ODgyNg==',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/798826?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/bufferapp',
#        'html_url': 'https://github.com/bufferapp',
#        'followers_url': 'https://api.github.com/users/bufferapp/followers',
#        'following_url': 'https://api.github.com/users/bufferapp/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/bufferapp/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/bufferapp/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/bufferapp/subscriptions',
#        'organizations_url': 'https://api.github.com/users/bufferapp/orgs',
#        'repos_url': 'https://api.github.com/users/bufferapp/repos',
#        'events_url': 'https://api.github.com/users/bufferapp/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/bufferapp/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/bufferapp/buffer-publish',
#       'description': 'Buffer Publish front-end single page application 🍩',
#       'fork': False,
#       'url': 'https://api.github.com/repos/bufferapp/buffer-publish',
#       'forks_url': 'https://api.github.com/repos/bufferapp/buffer-publish/forks',
#       'keys_url': 'https://api.github.com/repos/bufferapp/buffer-publish/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/bufferapp/buffer-publish/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/bufferapp/buffer-publish/teams',
#       'hooks_url': 'https://api.github.com/repos/bufferapp/buffer-publish/hooks',
#       'issue_events_url': 'https://api.github.com/repos/bufferapp/buffer-publish/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/bufferapp/buffer-publish/events',
#       'assignees_url': 'https://api.github.com/repos/bufferapp/buffer-publish/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/bufferapp/buffer-publish/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/bufferapp/buffer-publish/tags',
#       'blobs_url': 'https://api.github.com/repos/bufferapp/buffer-publish/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/bufferapp/buffer-publish/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/bufferapp/buffer-publish/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/bufferapp/buffer-publish/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/bufferapp/buffer-publish/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/bufferapp/buffer-publish/languages',
#       'stargazers_url': 'https://api.github.com/repos/bufferapp/buffer-publish/stargazers',
#       'contributors_url': 'https://api.github.com/repos/bufferapp/buffer-publish/contributors',
#       'subscribers_url': 'https://api.github.com/repos/bufferapp/buffer-publish/subscribers',
#       'subscription_url': 'https://api.github.com/repos/bufferapp/buffer-publish/subscription',
#       'commits_url': 'https://api.github.com/repos/bufferapp/buffer-publish/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/bufferapp/buffer-publish/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/bufferapp/buffer-publish/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/bufferapp/buffer-publish/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/bufferapp/buffer-publish/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/bufferapp/buffer-publish/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/bufferapp/buffer-publish/merges',
#       'archive_url': 'https://api.github.com/repos/bufferapp/buffer-publish/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/bufferapp/buffer-publish/downloads',
#       'issues_url': 'https://api.github.com/repos/bufferapp/buffer-publish/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/bufferapp/buffer-publish/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/bufferapp/buffer-publish/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/bufferapp/buffer-publish/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/bufferapp/buffer-publish/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/bufferapp/buffer-publish/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/bufferapp/buffer-publish/deployments',
#       'created_at': '2016-12-10T01:15:20Z',
#       'updated_at': '2019-12-05T09:42:35Z',
#       'pushed_at': '2019-12-05T13:00:40Z',
#       'git_url': 'git://github.com/bufferapp/buffer-publish.git',
#       'ssh_url': 'git@github.com:bufferapp/buffer-publish.git',
#       'clone_url': 'https://github.com/bufferapp/buffer-publish.git',
#       'svn_url': 'https://github.com/bufferapp/buffer-publish',
#       'homepage': 'https://publish.buffer.com',
#       'size': 23391,
#       'stargazers_count': 70,
#       'watchers_count': 70,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 14,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 28,
#       'license': None,
#       'forks': 14,
#       'open_issues': 28,
#       'watchers': 70,
#       'default_branch': 'master'}},
#     'base': {'label': 'bufferapp:master',
#      'ref': 'master',
#      'sha': 'c143cd0aaef8af1bd460068ae05638118bec15f4',
#      'user': {'login': 'bufferapp',
#       'id': 798826,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc5ODgyNg==',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/798826?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/bufferapp',
#       'html_url': 'https://github.com/bufferapp',
#       'followers_url': 'https://api.github.com/users/bufferapp/followers',
#       'following_url': 'https://api.github.com/users/bufferapp/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/bufferapp/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/bufferapp/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/bufferapp/subscriptions',
#       'organizations_url': 'https://api.github.com/users/bufferapp/orgs',
#       'repos_url': 'https://api.github.com/users/bufferapp/repos',
#       'events_url': 'https://api.github.com/users/bufferapp/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/bufferapp/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 76082423,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk3NjA4MjQyMw==',
#       'name': 'buffer-publish',
#       'full_name': 'bufferapp/buffer-publish',
#       'private': False,
#       'owner': {'login': 'bufferapp',
#        'id': 798826,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc5ODgyNg==',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/798826?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/bufferapp',
#        'html_url': 'https://github.com/bufferapp',
#        'followers_url': 'https://api.github.com/users/bufferapp/followers',
#        'following_url': 'https://api.github.com/users/bufferapp/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/bufferapp/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/bufferapp/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/bufferapp/subscriptions',
#        'organizations_url': 'https://api.github.com/users/bufferapp/orgs',
#        'repos_url': 'https://api.github.com/users/bufferapp/repos',
#        'events_url': 'https://api.github.com/users/bufferapp/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/bufferapp/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/bufferapp/buffer-publish',
#       'description': 'Buffer Publish front-end single page application 🍩',
#       'fork': False,
#       'url': 'https://api.github.com/repos/bufferapp/buffer-publish',
#       'forks_url': 'https://api.github.com/repos/bufferapp/buffer-publish/forks',
#       'keys_url': 'https://api.github.com/repos/bufferapp/buffer-publish/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/bufferapp/buffer-publish/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/bufferapp/buffer-publish/teams',
#       'hooks_url': 'https://api.github.com/repos/bufferapp/buffer-publish/hooks',
#       'issue_events_url': 'https://api.github.com/repos/bufferapp/buffer-publish/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/bufferapp/buffer-publish/events',
#       'assignees_url': 'https://api.github.com/repos/bufferapp/buffer-publish/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/bufferapp/buffer-publish/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/bufferapp/buffer-publish/tags',
#       'blobs_url': 'https://api.github.com/repos/bufferapp/buffer-publish/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/bufferapp/buffer-publish/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/bufferapp/buffer-publish/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/bufferapp/buffer-publish/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/bufferapp/buffer-publish/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/bufferapp/buffer-publish/languages',
#       'stargazers_url': 'https://api.github.com/repos/bufferapp/buffer-publish/stargazers',
#       'contributors_url': 'https://api.github.com/repos/bufferapp/buffer-publish/contributors',
#       'subscribers_url': 'https://api.github.com/repos/bufferapp/buffer-publish/subscribers',
#       'subscription_url': 'https://api.github.com/repos/bufferapp/buffer-publish/subscription',
#       'commits_url': 'https://api.github.com/repos/bufferapp/buffer-publish/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/bufferapp/buffer-publish/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/bufferapp/buffer-publish/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/bufferapp/buffer-publish/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/bufferapp/buffer-publish/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/bufferapp/buffer-publish/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/bufferapp/buffer-publish/merges',
#       'archive_url': 'https://api.github.com/repos/bufferapp/buffer-publish/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/bufferapp/buffer-publish/downloads',
#       'issues_url': 'https://api.github.com/repos/bufferapp/buffer-publish/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/bufferapp/buffer-publish/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/bufferapp/buffer-publish/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/bufferapp/buffer-publish/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/bufferapp/buffer-publish/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/bufferapp/buffer-publish/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/bufferapp/buffer-publish/deployments',
#       'created_at': '2016-12-10T01:15:20Z',
#       'updated_at': '2019-12-05T09:42:35Z',
#       'pushed_at': '2019-12-05T13:00:40Z',
#       'git_url': 'git://github.com/bufferapp/buffer-publish.git',
#       'ssh_url': 'git@github.com:bufferapp/buffer-publish.git',
#       'clone_url': 'https://github.com/bufferapp/buffer-publish.git',
#       'svn_url': 'https://github.com/bufferapp/buffer-publish',
#       'homepage': 'https://publish.buffer.com',
#       'size': 23391,
#       'stargazers_count': 70,
#       'watchers_count': 70,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 14,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 28,
#       'license': None,
#       'forks': 14,
#       'open_issues': 28,
#       'watchers': 70,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/bufferapp/buffer-publish/pulls/1121'},
#      'html': {'href': 'https://github.com/bufferapp/buffer-publish/pull/1121'},
#      'issue': {'href': 'https://api.github.com/repos/bufferapp/buffer-publish/issues/1121'},
#      'comments': {'href': 'https://api.github.com/repos/bufferapp/buffer-publish/issues/1121/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/bufferapp/buffer-publish/pulls/1121/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/bufferapp/buffer-publish/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/bufferapp/buffer-publish/pulls/1121/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/bufferapp/buffer-publish/statuses/c2c3f7990803d81ec63aa61a476230942e92c839'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'anafilipadealmeida',
#      'id': 16758464,
#      'node_id': 'MDQ6VXNlcjE2NzU4NDY0',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/16758464?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/anafilipadealmeida',
#      'html_url': 'https://github.com/anafilipadealmeida',
#      'followers_url': 'https://api.github.com/users/anafilipadealmeida/followers',
#      'following_url': 'https://api.github.com/users/anafilipadealmeida/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/anafilipadealmeida/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/anafilipadealmeida/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/anafilipadealmeida/subscriptions',
#      'organizations_url': 'https://api.github.com/users/anafilipadealmeida/orgs',
#      'repos_url': 'https://api.github.com/users/anafilipadealmeida/repos',
#      'events_url': 'https://api.github.com/users/anafilipadealmeida/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/anafilipadealmeida/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 5,
#     'additions': 48,
#     'deletions': 75,
#     'changed_files': 3}},
#   'public': True,
#   'created_at': '2019-12-05T13:00:41Z',
#   'org': {'id': 798826,
#    'login': 'bufferapp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/bufferapp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/798826?'}},
#  {'id': '11019584896',
#   'type': 'CreateEvent',
#   'actor': {'id': 55676016,
#    'login': '410606206',
#    'display_login': '410606206',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/410606206',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55676016?'},
#   'repo': {'id': 226103320,
#    'name': '410606206/Deep-learning',
#    'url': 'https://api.github.com/repos/410606206/Deep-learning'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': '智慧型系統',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-05T13:00:41Z'},
#  {'id': '11019584886',
#   'type': 'PushEvent',
#   'actor': {'id': 28490222,
#    'login': 'kodiccloud100',
#    'display_login': 'kodiccloud100',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kodiccloud100',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28490222?'},
#   'repo': {'id': 225989331,
#    'name': 'kodiccloud100/Lincoln',
#    'url': 'https://api.github.com/repos/kodiccloud100/Lincoln'},
#   'payload': {'push_id': 4359425434,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1e6e4f2400abf2c99f22e5711738b25d67f49326',
#    'before': '677e3184c02fceba019bb6c648238d06ca085fe0',
#    'commits': [{'sha': '1e6e4f2400abf2c99f22e5711738b25d67f49326',
#      'author': {'email': 'kodiccloud100@mailinator.com',
#       'name': 'kodiccloud100'},
#      'message': 'GIT CloneShare Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kodiccloud100/Lincoln/commits/1e6e4f2400abf2c99f22e5711738b25d67f49326'}]},
#   'public': True,
#   'created_at': '2019-12-05T13:00:41Z'},
#  {'id': '11019584883',
#   'type': 'CreateEvent',
#   'actor': {'id': 56154782,
#    'login': 'Hor123Fourmies',
#    'display_login': 'Hor123Fourmies',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Hor123Fourmies',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56154782?'},
#   'repo': {'id': 226103055,
#    'name': 'Hor123Fourmies/tri-selectif-correction',
#    'url': 'https://api.github.com/repos/Hor123Fourmies/tri-selectif-correction'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-05T13:00:41Z'},
#  {'id': '11019584878',
#   'type': 'PushEvent',
#   'actor': {'id': 30367100,
#    'login': 'AleksandrGanov',
#    'display_login': 'AleksandrGanov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AleksandrGanov',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30367100?'},
#   'repo': {'id': 216780598,
#    'name': 'AleksandrGanov/GeekBrains',
#    'url': 'https://api.github.com/repos/AleksandrGanov/GeekBrains'},
#   'payload': {'push_id': 4359425449,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'cbaa0dd0748ab6f5a9b33f09160eead9da89cb4a',
#    'before': '90b01203085ae5301cf9e5cd81456e55d000b590',
#    'commits': [{'sha': 'cbaa0dd0748ab6f5a9b33f09160eead9da89cb4a',
#      'author': {'email': 'gaa8008@gmail.com', 'name': 'Ganov Aleksandr'},
#      'message': 'BaseCommit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AleksandrGanov/GeekBrains/commits/cbaa0dd0748ab6f5a9b33f09160eead9da89cb4a'}]},
#   'public': True,
#   'created_at': '2019-12-05T13:00:41Z'},
#  {'id': '11019584893',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 33988894,
#    'login': 'riwn',
#    'display_login': 'riwn',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/riwn',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33988894?'},
#   'repo': {'id': 217702882,
#    'name': 'riwn/I_wanna_wiki',
#    'url': 'https://api.github.com/repos/riwn/I_wanna_wiki'},
#   'payload': {'action': 'closed',
#    'number': 81,
#    'pull_request': {'url': 'https://api.github.com/repos/riwn/I_wanna_wiki/pulls/81',
#     'id': 349428957,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ5NDI4OTU3',
#     'html_url': 'https://github.com/riwn/I_wanna_wiki/pull/81',
#     'diff_url': 'https://github.com/riwn/I_wanna_wiki/pull/81.diff',
#     'patch_url': 'https://github.com/riwn/I_wanna_wiki/pull/81.patch',
#     'issue_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/issues/81',
#     'number': 81,
#     'state': 'closed',
#     'locked': False,
#     'title': '長すぎる文字列のときにTwitterエラーが発生するバグの修正',
#     'user': {'login': 'riwn',
#      'id': 33988894,
#      'node_id': 'MDQ6VXNlcjMzOTg4ODk0',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/33988894?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/riwn',
#      'html_url': 'https://github.com/riwn',
#      'followers_url': 'https://api.github.com/users/riwn/followers',
#      'following_url': 'https://api.github.com/users/riwn/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/riwn/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/riwn/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/riwn/subscriptions',
#      'organizations_url': 'https://api.github.com/users/riwn/orgs',
#      'repos_url': 'https://api.github.com/users/riwn/repos',
#      'events_url': 'https://api.github.com/users/riwn/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/riwn/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2019-12-05T13:00:30Z',
#     'updated_at': '2019-12-05T13:00:41Z',
#     'closed_at': '2019-12-05T13:00:40Z',
#     'merged_at': '2019-12-05T13:00:40Z',
#     'merge_commit_sha': 'e51f388d6f13b5de54e955ae91e11d425c4904e4',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/pulls/81/commits',
#     'review_comments_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/pulls/81/comments',
#     'review_comment_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/issues/81/comments',
#     'statuses_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/statuses/360cd95f5291a3dfd7fa696a8bc3384524c756e6',
#     'head': {'label': 'riwn:Develop',
#      'ref': 'Develop',
#      'sha': '360cd95f5291a3dfd7fa696a8bc3384524c756e6',
#      'user': {'login': 'riwn',
#       'id': 33988894,
#       'node_id': 'MDQ6VXNlcjMzOTg4ODk0',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/33988894?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/riwn',
#       'html_url': 'https://github.com/riwn',
#       'followers_url': 'https://api.github.com/users/riwn/followers',
#       'following_url': 'https://api.github.com/users/riwn/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/riwn/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/riwn/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/riwn/subscriptions',
#       'organizations_url': 'https://api.github.com/users/riwn/orgs',
#       'repos_url': 'https://api.github.com/users/riwn/repos',
#       'events_url': 'https://api.github.com/users/riwn/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/riwn/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 217702882,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTc3MDI4ODI=',
#       'name': 'I_wanna_wiki',
#       'full_name': 'riwn/I_wanna_wiki',
#       'private': False,
#       'owner': {'login': 'riwn',
#        'id': 33988894,
#        'node_id': 'MDQ6VXNlcjMzOTg4ODk0',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/33988894?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/riwn',
#        'html_url': 'https://github.com/riwn',
#        'followers_url': 'https://api.github.com/users/riwn/followers',
#        'following_url': 'https://api.github.com/users/riwn/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/riwn/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/riwn/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/riwn/subscriptions',
#        'organizations_url': 'https://api.github.com/users/riwn/orgs',
#        'repos_url': 'https://api.github.com/users/riwn/repos',
#        'events_url': 'https://api.github.com/users/riwn/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/riwn/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/riwn/I_wanna_wiki',
#       'description': 'I wanna be the guy fan game site for Japanese',
#       'fork': False,
#       'url': 'https://api.github.com/repos/riwn/I_wanna_wiki',
#       'forks_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/forks',
#       'keys_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/teams',
#       'hooks_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/hooks',
#       'issue_events_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/events',
#       'assignees_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/tags',
#       'blobs_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/languages',
#       'stargazers_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/stargazers',
#       'contributors_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/contributors',
#       'subscribers_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/subscribers',
#       'subscription_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/subscription',
#       'commits_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/merges',
#       'archive_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/downloads',
#       'issues_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/deployments',
#       'created_at': '2019-10-26T12:05:29Z',
#       'updated_at': '2019-12-05T12:30:31Z',
#       'pushed_at': '2019-12-05T13:00:40Z',
#       'git_url': 'git://github.com/riwn/I_wanna_wiki.git',
#       'ssh_url': 'git@github.com:riwn/I_wanna_wiki.git',
#       'clone_url': 'https://github.com/riwn/I_wanna_wiki.git',
#       'svn_url': 'https://github.com/riwn/I_wanna_wiki',
#       'homepage': None,
#       'size': 1562,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Ruby',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'riwn:master',
#      'ref': 'master',
#      'sha': 'f3a93ce28980f480d95125026686c2a2c69650a3',
#      'user': {'login': 'riwn',
#       'id': 33988894,
#       'node_id': 'MDQ6VXNlcjMzOTg4ODk0',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/33988894?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/riwn',
#       'html_url': 'https://github.com/riwn',
#       'followers_url': 'https://api.github.com/users/riwn/followers',
#       'following_url': 'https://api.github.com/users/riwn/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/riwn/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/riwn/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/riwn/subscriptions',
#       'organizations_url': 'https://api.github.com/users/riwn/orgs',
#       'repos_url': 'https://api.github.com/users/riwn/repos',
#       'events_url': 'https://api.github.com/users/riwn/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/riwn/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 217702882,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTc3MDI4ODI=',
#       'name': 'I_wanna_wiki',
#       'full_name': 'riwn/I_wanna_wiki',
#       'private': False,
#       'owner': {'login': 'riwn',
#        'id': 33988894,
#        'node_id': 'MDQ6VXNlcjMzOTg4ODk0',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/33988894?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/riwn',
#        'html_url': 'https://github.com/riwn',
#        'followers_url': 'https://api.github.com/users/riwn/followers',
#        'following_url': 'https://api.github.com/users/riwn/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/riwn/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/riwn/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/riwn/subscriptions',
#        'organizations_url': 'https://api.github.com/users/riwn/orgs',
#        'repos_url': 'https://api.github.com/users/riwn/repos',
#        'events_url': 'https://api.github.com/users/riwn/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/riwn/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/riwn/I_wanna_wiki',
#       'description': 'I wanna be the guy fan game site for Japanese',
#       'fork': False,
#       'url': 'https://api.github.com/repos/riwn/I_wanna_wiki',
#       'forks_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/forks',
#       'keys_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/teams',
#       'hooks_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/hooks',
#       'issue_events_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/events',
#       'assignees_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/tags',
#       'blobs_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/languages',
#       'stargazers_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/stargazers',
#       'contributors_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/contributors',
#       'subscribers_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/subscribers',
#       'subscription_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/subscription',
#       'commits_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/merges',
#       'archive_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/downloads',
#       'issues_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/riwn/I_wanna_wiki/deployments',
#       'created_at': '2019-10-26T12:05:29Z',
#       'updated_at': '2019-12-05T12:30:31Z',
#       'pushed_at': '2019-12-05T13:00:40Z',
#       'git_url': 'git://github.com/riwn/I_wanna_wiki.git',
#       'ssh_url': 'git@github.com:riwn/I_wanna_wiki.git',
#       'clone_url': 'https://github.com/riwn/I_wanna_wiki.git',
#       'svn_url': 'https://github.com/riwn/I_wanna_wiki',
#       'homepage': None,
#       'size': 1562,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Ruby',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/riwn/I_wanna_wiki/pulls/81'},
#      'html': {'href': 'https://github.com/riwn/I_wanna_wiki/pull/81'},
#      'issue': {'href': 'https://api.github.com/repos/riwn/I_wanna_wiki/issues/81'},
#      'comments': {'href': 'https://api.github.com/repos/riwn/I_wanna_wiki/issues/81/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/riwn/I_wanna_wiki/pulls/81/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/riwn/I_wanna_wiki/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/riwn/I_wanna_wiki/pulls/81/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/riwn/I_wanna_wiki/statuses/360cd95f5291a3dfd7fa696a8bc3384524c756e6'}},
#     'author_association': 'OWNER',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'riwn',
#      'id': 33988894,
#      'node_id': 'MDQ6VXNlcjMzOTg4ODk0',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/33988894?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/riwn',
#      'html_url': 'https://github.com/riwn',
#      'followers_url': 'https://api.github.com/users/riwn/followers',
#      'following_url': 'https://api.github.com/users/riwn/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/riwn/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/riwn/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/riwn/subscriptions',
#      'organizations_url': 'https://api.github.com/users/riwn/orgs',
#      'repos_url': 'https://api.github.com/users/riwn/repos',
#      'events_url': 'https://api.github.com/users/riwn/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/riwn/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 14,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2019-12-05T13:00:41Z'},
#  {'id': '11019584875',
#   'type': 'CreateEvent',
#   'actor': {'id': 848087,
#    'login': 'situkangsayur',
#    'display_login': 'situkangsayur',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/situkangsayur',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/848087?'},
#   'repo': {'id': 226102910,
#    'name': 'situkangsayur/agit-tam-app',
#    'url': 'https://api.github.com/repos/situkangsayur/agit-tam-app'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-05T13:00:41Z'},
#  {'id': '11019584880',
#   'type': 'PushEvent',
#   'actor': {'id': 42855440,
#    'login': 'labour-camp',
#    'display_login': 'labour-camp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/labour-camp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42855440?'},
#   'repo': {'id': 168900832,
#    'name': 'labour-camp/labour-camp.github.io',
#    'url': 'https://api.github.com/repos/labour-camp/labour-camp.github.io'},
#   'payload': {'push_id': 4359425450,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0167d3c9dacc51f342725b0ee3b87a26c3371bef',
#    'before': 'e532f9da2846bfc566d4f16b147d54d32dd01d2b',
#    'commits': [{'sha': '0167d3c9dacc51f342725b0ee3b87a26c3371bef',
#      'author': {'email': 'lixiaoming1212@gmail.com', 'name': 'labour-camp'},
#      'message': 'ok',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/labour-camp/labour-camp.github.io/commits/0167d3c9dacc51f342725b0ee3b87a26c3371bef'}]},
#   'public': True,
#   'created_at': '2019-12-05T13:00:41Z'},
#  {'id': '11019584864',
#   'type': 'PushEvent',
#   'actor': {'id': 58263872,
#    'login': 'wangsheng-wangsheng',
#    'display_login': 'wangsheng-wangsheng',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wangsheng-wangsheng',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58263872?'},
#   'repo': {'id': 225780955,
#    'name': 'wangsheng-wangsheng/bysj',
#    'url': 'https://api.github.com/repos/wangsheng-wangsheng/bysj'},
#   'payload': {'push_id': 4359425431,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd651aae7de7b67f20186bd397f52e778e829f74d',
#    'before': '54f07fc8323562d86015b5e4d613aba0dfcc0474',
#    'commits': [{'sha': 'd651aae7de7b67f20186bd397f52e778e829f74d',
#      'author': {'email': '1251514221@qq.com', 'name': 'WangSheng'},
#      'message': 'gradle',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wangsheng-wangsheng/bysj/commits/d651aae7de7b67f20186bd397f52e778e829f74d'}]},
#   'public': True,
#   'created_at': '2019-12-05T13:00:41Z'},
#  {'id': '11019584846',
#   'type': 'PushEvent',
#   'actor': {'id': 6289266,
#    'login': 'CheSF',
#    'display_login': 'CheSF',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CheSF',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6289266?'},
#   'repo': {'id': 226093270,
#    'name': 'CheSF/docs',
#    'url': 'https://api.github.com/repos/CheSF/docs'},
#   'payload': {'push_id': 4359425428,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c9efd8c00b1ba56d3a86b882f0818b1179427ee6',
#    'before': 'ed8d0ca81c65b323827dbb60ba54522428669211',
#    'commits': [{'sha': 'c9efd8c00b1ba56d3a86b882f0818b1179427ee6',
#      'author': {'email': 'che.j.rodriguez@gmail.com', 'name': 'Che Rodriguez'},
#      'message': 'Set theme jekyll-theme-cayman',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/CheSF/docs/commits/c9efd8c00b1ba56d3a86b882f0818b1179427ee6'}]},
#   'public': True,
#   'created_at': '2019-12-05T13:00:41Z'},
#  {'id': '11019584841',
#   'type': 'PushEvent',
#   'actor': {'id': 28707025,
#    'login': 'ytani01',
#    'display_login': 'ytani01',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ytani01',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28707025?'},
# ...
#       'subscription_url': 'https://api.github.com/repos/jeanphilippeD/routing/subscription',
#       'commits_url': 'https://api.github.com/repos/jeanphilippeD/routing/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jeanphilippeD/routing/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jeanphilippeD/routing/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jeanphilippeD/routing/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jeanphilippeD/routing/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jeanphilippeD/routing/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jeanphilippeD/routing/merges',
#       'archive_url': 'https://api.github.com/repos/jeanphilippeD/routing/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jeanphilippeD/routing/downloads',
#       'issues_url': 'https://api.github.com/repos/jeanphilippeD/routing/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jeanphilippeD/routing/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jeanphilippeD/routing/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jeanphilippeD/routing/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jeanphilippeD/routing/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jeanphilippeD/routing/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jeanphilippeD/routing/deployments',
#       'created_at': '2019-02-04T09:07:43Z',
#       'updated_at': '2019-07-11T10:17:25Z',
#       'pushed_at': '2019-12-05T10:52:24Z',
#       'git_url': 'git://github.com/jeanphilippeD/routing.git',
#       'ssh_url': 'git@github.com:jeanphilippeD/routing.git',
#       'clone_url': 'https://github.com/jeanphilippeD/routing.git',
#       'svn_url': 'https://github.com/jeanphilippeD/routing',
#       'homepage': None,
#       'size': 115820,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Rust',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'maidsafe:fleming',
#      'ref': 'fleming',
#      'sha': 'bf16edcc213a8888a2be0c58fc88135fcd0b0a47',
#      'user': {'login': 'maidsafe',
#       'id': 536423,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUzNjQyMw==',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/536423?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/maidsafe',
#       'html_url': 'https://github.com/maidsafe',
#       'followers_url': 'https://api.github.com/users/maidsafe/followers',
#       'following_url': 'https://api.github.com/users/maidsafe/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/maidsafe/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/maidsafe/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/maidsafe/subscriptions',
#       'organizations_url': 'https://api.github.com/users/maidsafe/orgs',
#       'repos_url': 'https://api.github.com/users/maidsafe/repos',
#       'events_url': 'https://api.github.com/users/maidsafe/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/maidsafe/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 31270514,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMTI3MDUxNA==',
#       'name': 'routing',
#       'full_name': 'maidsafe/routing',
#       'private': False,
#       'owner': {'login': 'maidsafe',
#        'id': 536423,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUzNjQyMw==',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/536423?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/maidsafe',
#        'html_url': 'https://github.com/maidsafe',
#        'followers_url': 'https://api.github.com/users/maidsafe/followers',
#        'following_url': 'https://api.github.com/users/maidsafe/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/maidsafe/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/maidsafe/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/maidsafe/subscriptions',
#        'organizations_url': 'https://api.github.com/users/maidsafe/orgs',
#        'repos_url': 'https://api.github.com/users/maidsafe/repos',
#        'events_url': 'https://api.github.com/users/maidsafe/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/maidsafe/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/maidsafe/routing',
#       'description': 'Routing - specialised storage DHT',
#       'fork': False,
#       'url': 'https://api.github.com/repos/maidsafe/routing',
#       'forks_url': 'https://api.github.com/repos/maidsafe/routing/forks',
#       'keys_url': 'https://api.github.com/repos/maidsafe/routing/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/maidsafe/routing/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/maidsafe/routing/teams',
#       'hooks_url': 'https://api.github.com/repos/maidsafe/routing/hooks',
#       'issue_events_url': 'https://api.github.com/repos/maidsafe/routing/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/maidsafe/routing/events',
#       'assignees_url': 'https://api.github.com/repos/maidsafe/routing/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/maidsafe/routing/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/maidsafe/routing/tags',
#       'blobs_url': 'https://api.github.com/repos/maidsafe/routing/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/maidsafe/routing/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/maidsafe/routing/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/maidsafe/routing/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/maidsafe/routing/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/maidsafe/routing/languages',
#       'stargazers_url': 'https://api.github.com/repos/maidsafe/routing/stargazers',
#       'contributors_url': 'https://api.github.com/repos/maidsafe/routing/contributors',
#       'subscribers_url': 'https://api.github.com/repos/maidsafe/routing/subscribers',
#       'subscription_url': 'https://api.github.com/repos/maidsafe/routing/subscription',
#       'commits_url': 'https://api.github.com/repos/maidsafe/routing/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/maidsafe/routing/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/maidsafe/routing/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/maidsafe/routing/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/maidsafe/routing/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/maidsafe/routing/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/maidsafe/routing/merges',
#       'archive_url': 'https://api.github.com/repos/maidsafe/routing/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/maidsafe/routing/downloads',
#       'issues_url': 'https://api.github.com/repos/maidsafe/routing/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/maidsafe/routing/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/maidsafe/routing/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/maidsafe/routing/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/maidsafe/routing/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/maidsafe/routing/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/maidsafe/routing/deployments',
#       'created_at': '2015-02-24T16:52:53Z',
#       'updated_at': '2019-12-04T16:48:25Z',
#       'pushed_at': '2019-12-05T10:52:26Z',
#       'git_url': 'git://github.com/maidsafe/routing.git',
#       'ssh_url': 'git@github.com:maidsafe/routing.git',
#       'clone_url': 'https://github.com/maidsafe/routing.git',
#       'svn_url': 'https://github.com/maidsafe/routing',
#       'homepage': None,
#       'size': 115788,
#       'stargazers_count': 209,
#       'watchers_count': 209,
#       'language': 'Rust',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 68,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 45,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 68,
#       'open_issues': 45,
#       'watchers': 209,
#       'default_branch': 'fleming'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/maidsafe/routing/pulls/1929'},
#      'html': {'href': 'https://github.com/maidsafe/routing/pull/1929'},
#      'issue': {'href': 'https://api.github.com/repos/maidsafe/routing/issues/1929'},
#      'comments': {'href': 'https://api.github.com/repos/maidsafe/routing/issues/1929/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/maidsafe/routing/pulls/1929/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/maidsafe/routing/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/maidsafe/routing/pulls/1929/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/maidsafe/routing/statuses/e43a300871a33b0ec16b0409f86f78ac7db0d6a2'}},
#     'author_association': 'CONTRIBUTOR'}},
#   'public': True,
#   'created_at': '2019-12-05T13:00:39Z',
#   'org': {'id': 536423,
#    'login': 'maidsafe',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/maidsafe',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/536423?'}},
#  {'id': '11019584770',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 11966374,
#    'login': 'beriniwlew',
#    'display_login': 'beriniwlew',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/beriniwlew',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11966374?'},
#   'repo': {'id': 12201538,
#    'name': 'aspnetboilerplate/aspnetboilerplate',
#    'url': 'https://api.github.com/repos/aspnetboilerplate/aspnetboilerplate'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/aspnetboilerplate/aspnetboilerplate/issues/4982',
#     'repository_url': 'https://api.github.com/repos/aspnetboilerplate/aspnetboilerplate',
#     'labels_url': 'https://api.github.com/repos/aspnetboilerplate/aspnetboilerplate/issues/4982/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/aspnetboilerplate/aspnetboilerplate/issues/4982/comments',
#     'events_url': 'https://api.github.com/repos/aspnetboilerplate/aspnetboilerplate/issues/4982/events',
#     'html_url': 'https://github.com/aspnetboilerplate/aspnetboilerplate/issues/4982',
#     'id': 516073740,
#     'node_id': 'MDU6SXNzdWU1MTYwNzM3NDA=',
#     'number': 4982,
#     'title': 'Update Angular UI to ngx-admin',
#     'user': {'login': 'beriniwlew',
#      'id': 11966374,
#      'node_id': 'MDQ6VXNlcjExOTY2Mzc0',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/11966374?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/beriniwlew',
#      'html_url': 'https://github.com/beriniwlew',
#      'followers_url': 'https://api.github.com/users/beriniwlew/followers',
#      'following_url': 'https://api.github.com/users/beriniwlew/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/beriniwlew/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/beriniwlew/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/beriniwlew/subscriptions',
#      'organizations_url': 'https://api.github.com/users/beriniwlew/orgs',
#      'repos_url': 'https://api.github.com/users/beriniwlew/repos',
#      'events_url': 'https://api.github.com/users/beriniwlew/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/beriniwlew/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1399102495,
#       'node_id': 'MDU6TGFiZWwxMzk5MTAyNDk1',
#       'url': 'https://api.github.com/repos/aspnetboilerplate/aspnetboilerplate/labels/aspnetboilerplate-templates',
#       'name': 'aspnetboilerplate-templates',
#       'color': 'f7bbbc',
#       'default': False,
#       'description': ''},
#      {'id': 227428555,
#       'node_id': 'MDU6TGFiZWwyMjc0Mjg1NTU=',
#       'url': 'https://api.github.com/repos/aspnetboilerplate/aspnetboilerplate/labels/discussion',
#       'name': 'discussion',
#       'color': 'bfdadc',
#       'default': False,
#       'description': None}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 17,
#     'created_at': '2019-11-01T12:07:30Z',
#     'updated_at': '2019-12-05T13:00:40Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'body': 'I think I may spend some time porting over the AngularUI project over to ngx-admin.\r\n\r\nhttps://github.com/akveo/ngx-admin\r\n\r\nDemo:\r\nhttp://akveo.com/ngx-admin/pages/dashboard\r\n\r\nJust want to know how the community here feels about that.  '},
#    'comment': {'url': 'https://api.github.com/repos/aspnetboilerplate/aspnetboilerplate/issues/comments/562119305',
#     'html_url': 'https://github.com/aspnetboilerplate/aspnetboilerplate/issues/4982#issuecomment-562119305',
#     'issue_url': 'https://api.github.com/repos/aspnetboilerplate/aspnetboilerplate/issues/4982',
#     'id': 562119305,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2MjExOTMwNQ==',
#     'user': {'login': 'beriniwlew',
#      'id': 11966374,
#      'node_id': 'MDQ6VXNlcjExOTY2Mzc0',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/11966374?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/beriniwlew',
#      'html_url': 'https://github.com/beriniwlew',
#      'followers_url': 'https://api.github.com/users/beriniwlew/followers',
#      'following_url': 'https://api.github.com/users/beriniwlew/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/beriniwlew/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/beriniwlew/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/beriniwlew/subscriptions',
#      'organizations_url': 'https://api.github.com/users/beriniwlew/orgs',
#      'repos_url': 'https://api.github.com/users/beriniwlew/repos',
#      'events_url': 'https://api.github.com/users/beriniwlew/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/beriniwlew/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-05T13:00:40Z',
#     'updated_at': '2019-12-05T13:00:40Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': "There's a [starter-kit](https://github.com/akveo/ngx-admin/tree/starter-kit) branch for ngx-admin. \r\n\r\nPerhaps we should start from there?"}},
#   'public': True,
#   'created_at': '2019-12-05T13:00:40Z',
#   'org': {'id': 5957277,
#    'login': 'aspnetboilerplate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/aspnetboilerplate',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5957277?'}}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requ
# Out:
# '\nYour Code\n'
